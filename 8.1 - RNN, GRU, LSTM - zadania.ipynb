# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
os.environ['CUDA_VISIBLE_DEVICES'] = "-1"

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.callbacks import EarlyStopping
n_words = 5000
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.imdb.load_data(num_words=n_words)

es = EarlyStopping(monitor = "val_loss", mode = "min", patience = 5)

EPOCHS = 10000

#https://keras.io/api/datasets/imdb/

# %%
#Na podstawie poprzedniego pliku stwórz 4 modele:
#1. z warstwą embedding
#2. z warstwą embedding i warstwą SimpleRNN (zamiast flatten), wyposażoną w 32 neurony
#3. z warstwą embedding i warstwą GRU (zamiast flatten), wyposażoną w 32 neurony
#4. z warstwą embedding i warstwą LSTM (zamiast flatten), wyposażoną w 32 neurony
#Dla każdego modelu stwórz wykresy. Która sieć poradziła sobie najlepiej?
